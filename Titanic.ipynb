# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShakawatAlSakib/new-year/blob/master/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from matplotlib import pyplot as plt 
import numpy as np
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
import pandas as pd

# %%
train=pd.read_csv('gdrive/My Drive/Colab Notebooks/train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...  Parch     Fare  Embarked  Title
# 0             1         0       3    0  ...      0   7.2500         0    0.0
# 1             2         1       1    1  ...      0  71.2833         1    2.0
# 2             3         1       3    1  ...      0   7.9250         0    1.0
# 3             4         1       1    1  ...      0  53.1000         0    2.0
# 4             5         0       3    0  ...      0   8.0500         0    0.0
# ..          ...       ...     ...  ...  ...    ...      ...       ...    ...
# 95           96         0       3    0  ...      0   8.0500         0    0.0
# 96           97         0       1    0  ...      0  34.6542         1    0.0
# 97           98         1       1    0  ...      1  63.3583         1    0.0
# 98           99         1       2    1  ...      1  23.0000         0    2.0
# 99          100         0       2    0  ...      0  26.0000         0    0.0
#
# [100 rows x 10 columns]

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
def bar_chart(feature):
  survived=train[train['Survived']==1][feature].value_counts()
  dead=train[train['Survived']==0][feature].value_counts()
  df=pd.DataFrame([survived,dead])
  df.index=['Survived','Dead']
  df.plot(kind='bar', stacked=True ,figsize=(10,5))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0             1         0       3  ...   7.2500   NaN         S
# 1             2         1       1  ...  71.2833   C85         C
# 2             3         1       3  ...   7.9250   NaN         S
# 3             4         1       1  ...  53.1000  C123         S
# 4             5         0       3  ...   8.0500   NaN         S
# 5             6         0       3  ...   8.4583   NaN         Q
# 6             7         0       1  ...  51.8625   E46         S
# 7             8         0       3  ...  21.0750   NaN         S
# 8             9         1       3  ...  11.1333   NaN         S
# 9            10         1       2  ...  30.0708   NaN         C
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 12           13         0       3  ...   8.0500   NaN         S
# 13           14         0       3  ...  31.2750   NaN         S
# ...

# %%
train_test_data=[train]
for dataset in train_test_data:
  dataset['Title']=dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  ... Cabin Embarked   Title
# 0             1         0       3  ...   NaN        S      Mr
# 1             2         1       1  ...   C85        C     Mrs
# 2             3         1       3  ...   NaN        S    Miss
# 3             4         1       1  ...  C123        S     Mrs
# 4             5         0       3  ...   NaN        S      Mr
# 5             6         0       3  ...   NaN        Q      Mr
# 6             7         0       1  ...   E46        S      Mr
# 7             8         0       3  ...   NaN        S  Master
# 8             9         1       3  ...   NaN        S     Mrs
# 9            10         1       2  ...   NaN        C     Mrs
# 10           11         1       3  ...    G6        S    Miss
# 11           12         1       1  ...  C103        S    Miss
# 12           13         0       3  ...   NaN        S      Mr
# 13           14         0       3  ...   NaN        S      Mr
# ...

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Col           2
# Major         2
# Capt          1
# Ms            1
# Countess      1
# Sir           1
# Don           1
# Jonkheer      1
# Lady          1
# Mme           1
# Name: Title, dtype: int64

# %%
Title_mapping={"Mr":0, "Miss":1,"Mrs":2,"Master":3,"Dr":3,"Rev":3,"Mlle":3,"Col":3,"Major":3,"Capt":3,"Ms":3,"Countess":3,"Sir":3,"Sir":3,"Don":3,"Jonkheer":3,"Lady":3,"Mm3":3}

# %%
for dataset in train_test_data:
  dataset['Title']=dataset['Title'].map(Title_mapping)

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  ... Cabin Embarked  Title
# 0             1         0       3  ...   NaN        S    0.0
# 1             2         1       1  ...   C85        C    2.0
# 2             3         1       3  ...   NaN        S    1.0
# 3             4         1       1  ...  C123        S    2.0
# 4             5         0       3  ...   NaN        S    0.0
# 5             6         0       3  ...   NaN        Q    0.0
# 6             7         0       1  ...   E46        S    0.0
# 7             8         0       3  ...   NaN        S    3.0
# 8             9         1       3  ...   NaN        S    2.0
# 9            10         1       2  ...   NaN        C    2.0
# 10           11         1       3  ...    G6        S    1.0
# 11           12         1       1  ...  C103        S    1.0
# 12           13         0       3  ...   NaN        S    0.0
# 13           14         0       3  ...   NaN        S    0.0
# ...

# %%
train.drop('Name',axis=1,inplace=True)

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass     Sex  ...     Fare  Cabin  Embarked Title
# 0             1         0       3    male  ...   7.2500    NaN         S   0.0
# 1             2         1       1  female  ...  71.2833    C85         C   2.0
# 2             3         1       3  female  ...   7.9250    NaN         S   1.0
# 3             4         1       1  female  ...  53.1000   C123         S   2.0
# 4             5         0       3    male  ...   8.0500    NaN         S   0.0
# 5             6         0       3    male  ...   8.4583    NaN         Q   0.0
# 6             7         0       1    male  ...  51.8625    E46         S   0.0
# 7             8         0       3    male  ...  21.0750    NaN         S   3.0
# 8             9         1       3  female  ...  11.1333    NaN         S   2.0
# 9            10         1       2  female  ...  30.0708    NaN         C   2.0
# 10           11         1       3  female  ...  16.7000     G6         S   1.0
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            1
# dtype: int64

# %%
Gender_mapping={"male":0,"female":1}

# %%
for dataset in train_test_data:
  dataset['Sex']=dataset['Sex'].map(Gender_mapping)

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...     Fare  Cabin  Embarked Title
# 0             1         0       3    0  ...   7.2500    NaN         S   0.0
# 1             2         1       1    1  ...  71.2833    C85         C   2.0
# 2             3         1       3    1  ...   7.9250    NaN         S   1.0
# 3             4         1       1    1  ...  53.1000   C123         S   2.0
# 4             5         0       3    0  ...   8.0500    NaN         S   0.0
# 5             6         0       3    0  ...   8.4583    NaN         Q   0.0
# 6             7         0       1    0  ...  51.8625    E46         S   0.0
# 7             8         0       3    0  ...  21.0750    NaN         S   3.0
# 8             9         1       3    1  ...  11.1333    NaN         S   2.0
# 9            10         1       2    1  ...  30.0708    NaN         C   2.0
# 10           11         1       3    1  ...  16.7000     G6         S   1.0
# ...

# %%
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"),inplace=True)

# %%
train.groupby("Title")["Age"].transform("median")
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            1
# dtype: int64

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...     Fare  Cabin  Embarked Title
# 0             1         0       3    0  ...   7.2500    NaN         S   0.0
# 1             2         1       1    1  ...  71.2833    C85         C   2.0
# 2             3         1       3    1  ...   7.9250    NaN         S   1.0
# 3             4         1       1    1  ...  53.1000   C123         S   2.0
# 4             5         0       3    0  ...   8.0500    NaN         S   0.0
# 5             6         0       3    0  ...   8.4583    NaN         Q   0.0
# 6             7         0       1    0  ...  51.8625    E46         S   0.0
# 7             8         0       3    0  ...  21.0750    NaN         S   3.0
# 8             9         1       3    1  ...  11.1333    NaN         S   2.0
# 9            10         1       2    1  ...  30.0708    NaN         C   2.0
# 10           11         1       3    1  ...  16.7000     G6         S   1.0
# ...

# %%
facet=sns.FacetGrid(train,hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade=True)
facet.set(xlim=(0,train['Age'].max()))
facet.add_legend()
plt.show()

# %%
facet=sns.FacetGrid(train,hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade=True)
facet.set(xlim=(0,train['Age'].max()))
facet.add_legend()
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %%
for dataset in train_test_data:
  dataset.loc[dataset['Age']<=16,'Age']=0,
  dataset.loc[(dataset['Age']>16)&(dataset['Age']<=26),'Age']=1,
  dataset.loc[(dataset['Age']>26)&(dataset['Age']<=36),'Age']=2,
  dataset.loc[(dataset['Age']>36)&(dataset['Age']<=62),'Age']=3,
  dataset.loc[dataset['Age']>62,'Age']=4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-b3cd958f54d5> in <module>()
#       1 for dataset in train_test_data:
# ----> 2   dataset.loc[dataset['Age']<=16,'Age']=0,
#       3   dataset.loc[(dataset['Age']>16)&(dataset['Age']<=26),'Age']=1,
#       4   dataset.loc[(dataset['Age']>26)&(dataset['Age']<=36),'Age']=2,
#       5   dataset.loc[(dataset['Age']>36)&(dataset['Age']<=62),'Age']=3,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
# ...

# %%
Pclass1=train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2=train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3=train[train['Pclass']==3]['Embarked'].value_counts()
df=pd.DataFrame([Pclass1,Pclass2,Pclass3])
df.index=['1st class','2nd class','3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
for dataset in train_test_data:
  dataset['Embarked']=dataset['Embarked'].fillna('S')

# %%
train.isnull().sum()

# %%
embarked_mapping={"S":0,"C":1,"Q":2}
for dataset in train_test_data:
  dataset['Embarked']=dataset['Embarked'].map(embarked_mapping)

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...     Fare  Cabin  Embarked Title
# 0             1         0       3    0  ...   7.2500    NaN         0   0.0
# 1             2         1       1    1  ...  71.2833    C85         1   2.0
# 2             3         1       3    1  ...   7.9250    NaN         0   1.0
# 3             4         1       1    1  ...  53.1000   C123         0   2.0
# 4             5         0       3    0  ...   8.0500    NaN         0   0.0
# 5             6         0       3    0  ...   8.4583    NaN         2   0.0
# 6             7         0       1    0  ...  51.8625    E46         0   0.0
# 7             8         0       3    0  ...  21.0750    NaN         0   3.0
# 8             9         1       3    1  ...  11.1333    NaN         0   2.0
# 9            10         1       2    1  ...  30.0708    NaN         1   2.0
# 10           11         1       3    1  ...  16.7000     G6         0   1.0
# ...

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...     Fare  Cabin  Embarked Title
# 0             1         0       3    0  ...   7.2500    NaN         0   0.0
# 1             2         1       1    1  ...  71.2833    C85         1   2.0
# 2             3         1       3    1  ...   7.9250    NaN         0   1.0
# 3             4         1       1    1  ...  53.1000   C123         0   2.0
# 4             5         0       3    0  ...   8.0500    NaN         0   0.0
# 5             6         0       3    0  ...   8.4583    NaN         2   0.0
# 6             7         0       1    0  ...  51.8625    E46         0   0.0
# 7             8         0       3    0  ...  21.0750    NaN         0   3.0
# 8             9         1       3    1  ...  11.1333    NaN         0   2.0
# 9            10         1       2    1  ...  30.0708    NaN         1   2.0
# 10           11         1       3    1  ...  16.7000     G6         0   1.0
# ...

# %%
feature_drop=['Ticket' , 'Cabin']
train=train.drop(feature_drop , axis=1)

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  Sex  ...  Parch     Fare  Embarked  Title
# 0             1         0       3    0  ...      0   7.2500         0    0.0
# 1             2         1       1    1  ...      0  71.2833         1    2.0
# 2             3         1       3    1  ...      0   7.9250         0    1.0
# 3             4         1       1    1  ...      0  53.1000         0    2.0
# 4             5         0       3    0  ...      0   8.0500         0    0.0
# 5             6         0       3    0  ...      0   8.4583         2    0.0
# 6             7         0       1    0  ...      0  51.8625         0    0.0
# 7             8         0       3    0  ...      1  21.0750         0    3.0
# 8             9         1       3    1  ...      2  11.1333         0    2.0
# 9            10         1       2    1  ...      0  30.0708         1    2.0
# 10           11         1       3    1  ...      1  16.7000         0    1.0
# ...

# %%
train_data=train.drop('Survived',axis=1)
target=train['Survived']
train_data.shape , target.shape
# Out:
# ((891, 9), (891,))

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test =train_test_split(train_data,target, test_size=30, random_state=42)
print("x_train",x_train.shape)
print("x_test",x_test.shape)
print("y_train",y_train.shape)
print("y_test",y_test.shape)
print(y_test)
y_test.value_counts()
# Out:
# x_train (861, 9)
# x_test (30, 9)
# y_train (861,)
# y_test (30,)
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
# 290    1
# 300    1
# 333    0
# 208    1
# 136    1
# 137    0
# 696    0
# 485    0
# 244    0
# 344    0
# 853    1
# 621    1
# 653    1
# 886    0
# 110    0
# 294    0
# 447    1
# 192    1
# 682    0
# 538    0
# 819    0
# 30     0
# 673    1
# 63     0
# 396    0
# Name: Survived, dtype: int64
# 0    17
# 1    13
# Name: Survived, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-197-a60af4821756> in <module>()
#       1 dt=DecisionTreeClassifier()
# ----> 2 dt.fit(x_train, y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
#     151             if issparse(X):
#
# ...
